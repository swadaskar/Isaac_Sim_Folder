# %%
# Copyright (c) 2020-2021, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.

# %%
import getpass

user = getpass.getuser()
from omni.isaac.kit import SimulationApp

# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this
simulation_app = SimulationApp({"livesync_usd": f"omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd"})
# Out:
# Starting kit application with the following args:  ['/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts', '--ext-folder', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/apps', '--/physics/cudaDevice=0', '--portable', '--no-window']
# Passing the following args to the base kit application:  ['-f', '/home/lm-2023/.local/share/jupyter/runtime/kernel-139e8c86-5da8-431a-9080-b07f38d0f2c9.json']
# [Warning] [omni.isaac.kit.simulation_app] Modules: ['omni.isaac.kit.app_framework'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [omni.isaac.kit.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/logs/Kit/Isaac-Sim/2022.2/kit_20230621_120445.log
# 2023-06-21 19:04:45 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.lidar] Extensions config 'extension.toml' doesn't exist '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.lidar' or '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.lidar/config'
# 2023-06-21 19:04:45 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.radar] Extensions config 'extension.toml' doesn't exist '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.radar' or '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.radar/config'
# [0.150s] [ext: omni.stats-0.0.0] startup
# [0.173s] [ext: omni.rtx.shadercache-1.0.0] startup
# [0.176s] [ext: omni.assets.plugins-0.0.0] startup
# [0.177s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.182s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.187s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 530.30.02     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3080          | Yes: 0 |     | 10486   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2216      | acc370a7.. |
# |=============================================================================================|
# | OS: Linux lm2023-XPS-8950, Version: 5.15.0-75-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12013000 (1.20.13.0)
# | Processor: 12th Gen Intel(R) Core(TM) i7-12700 | Cores: Unknown | Logical: 20
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31816 | Free Memory: 23897
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# [0.715s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.719s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.721s] [ext: omni.kit.loop-isaac-1.0.0] startup
# [0.721s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.722s] [ext: omni.kit.test-0.0.0] startup
# [0.734s] [ext: omni.usd.config-1.0.0] startup
# [0.736s] [ext: omni.usd.libs-1.0.0] startup
# [0.838s] [ext: omni.isaac.core_archive-2.0.1] startup
# [0.930s] [ext: omni.pip.torch-1_13_1-0.1.4] startup
# [0.939s] [ext: omni.isaac.ml_archive-1.1.0] startup
# [0.977s] [ext: omni.client-0.1.1] startup
# [0.982s] [ext: omni.appwindow-1.0.1] startup
# [0.983s] [ext: omni.kit.renderer.core-0.0.0] startup
# [0.986s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.987s] [ext: omni.kit.renderer.imgui-0.0.0] startup
# [1.031s] [ext: carb.audio-0.1.0] startup
# [1.033s] [ext: omni.ui-2.14.4] startup
# [1.039s] [ext: omni.uiaudio-1.0.0] startup
# [1.040s] [ext: omni.kit.mainwindow-1.0.0] startup
# [1.040s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.040s] [ext: omni.usd.schema.physics-1.0.0] startup
# [1.066s] [ext: omni.usd.schema.isaac-1.1.0] startup
# [1.075s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.081s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.086s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [1.092s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.097s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.101s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.137s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.141s] [ext: omni.usd.schema.scene.visualization-1.0.0] startup
# [1.141s] [ext: omni.usd.schema.physx-0.0.0] startup
# [1.159s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.159s] [ext: omni.timeline-1.0.5] startup
# [1.160s] [ext: omni.kit.search_core-1.0.2] startup
# [1.161s] [ext: omni.hydra.scene_delegate-0.3.0] startup
# [1.165s] [ext: omni.kit.widget.path_field-2.0.4] startup
# [1.167s] [ext: omni.kit.widget.filebrowser-2.3.10] startup
# [1.199s] [ext: omni.kit.widget.browser_bar-2.0.5] startup
# [1.199s] [ext: omni.kit.window.popup_dialog-2.0.16] startup
# [1.201s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.203s] [ext: omni.usd.core-1.0.4] startup
# [1.205s] [ext: omni.kit.audiodeviceenum-1.0.0] startup
# [1.205s] [ext: omni.kit.widget.nucleus_connector-1.0.3] startup
# [1.206s] [ext: omni.kit.commands-1.4.5] startup
# [1.209s] [ext: omni.hydra.usdrt_delegate-4.3.2] startup
# [1.220s] [ext: omni.kit.notification_manager-1.0.5] startup
# [1.222s] [ext: omni.usd-1.6.30] startup
# [1.252s] [ext: omni.kit.widget.versioning-1.3.8] startup
# [1.253s] [ext: omni.iray.libs-0.0.0] startup
# [1.256s] [ext: omni.kit.window.filepicker-2.7.15] startup
# [1.286s] [ext: omni.mdl.neuraylib-0.1.0] startup
# [1.288s] [ext: omni.kit.collaboration.channel_manager-1.0.9] startup
# [1.289s] [ext: omni.kit.window.file_importer-1.0.10] startup
# [1.290s] [ext: omni.mdl-0.1.0] startup
# [1.304s] [ext: omni.kit.usd.layers-2.0.11] startup
# [1.310s] [ext: omni.kit.menu.utils-1.4.7] startup
# [1.316s] [ext: omni.kit.material.library-1.3.21] startup
# [1.320s] [ext: omni.kit.menu.create-1.0.8] startup
# [1.321s] [ext: omni.kit.clipboard-1.0.0] startup
# [1.321s] [ext: omni.kit.widget.graph-1.5.6-104_2] startup
# [1.337s] [ext: omni.kit.context_menu-1.5.12] startup
# [1.339s] [ext: omni.kit.window.extensions-1.1.1] startup
# [1.343s] [ext: omni.inspect-1.0.1] startup
# [1.345s] [ext: omni.kit.window.property-1.8.2] startup
# [1.346s] [ext: omni.kit.primitive.mesh-1.0.8] startup
# [1.348s] [ext: omni.graph.core-2.65.4] startup
# [1.351s] [ext: omni.isaac.version-1.0.0] startup
# [1.351s] [ext: omni.kit.stage_templates-1.1.13] startup
# [1.352s] [ext: omni.kit.usd_undo-0.1.2] startup
# [1.353s] [ext: omni.graph.tools-1.17.2] startup
# [1.363s] [ext: omni.ui.scene-1.5.18] startup
# [1.367s] [ext: omni.graph-1.50.2] startup
# [1.427s] [ext: omni.ui_query-1.1.1] startup
# [1.428s] [ext: omni.volume-0.1.0] startup
# [1.430s] [ext: omni.kit.ui_test-1.2.9] startup
# [1.431s] [ext: omni.hydra.rtx-0.1.0] startup
# [1.435s] [ext: omni.kit.widget.searchfield-1.0.10] startup
# [1.436s] [ext: omni.kit.graph.delegate.default-1.0.18] startup
# [1.438s] [ext: omni.debugdraw-0.1.1] startup
# [1.440s] [ext: omni.kit.graph.editor.core-1.4.7] startup
# [1.442s] [ext: omni.hydra.pxr-1.1.2] startup
# [1.446s] [ext: omni.activity.core-1.0.1] startup
# [1.448s] [ext: omni.kit.hydra_texture-1.0.11] startup
# [1.451s] [ext: omni.kit.viewport.legacy_gizmos-1.0.10] startup
# [1.454s] [ext: omni.kit.viewport.registry-104.0.2] startup
# [1.455s] [ext: omni.kit.widget.viewport-104.1.16] startup
# [1.456s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [1.457s] [ext: omni.kit.window.file_exporter-1.0.10] startup
# [1.457s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [1.460s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [1.460s] [ext: omni.kit.window.file-1.3.32] startup
# [1.462s] [ext: omni.kit.viewport.window-104.1.23] startup
# 2023-06-21 19:04:47 [1,458ms] [Warning] [omni.kit.ui.editor_menu] set_value menu Window/Viewport/Viewport 1 not found
# [1.480s] [ext: omni.kit.widget.settings-1.0.1] startup
# [1.481s] [ext: omni.kit.widget.stage-2.7.24] startup
# [1.484s] [ext: omni.kit.window.content_browser-2.6.8] startup
# [1.492s] [ext: omni.kit.viewport.utility-1.0.14] startup
# [1.493s] [ext: omni.kit.window.preferences-1.3.8] startup
# [1.512s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [1.513s] [ext: omni.kit.widget.prompt-1.0.5Warp 0.6.3 initialized:
#    CUDA Toolkit: 11.5, Driver: 12.1
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA GeForce RTX 3080 (sm_86)
#    Kernel cache: /home/lm-2023/.cache/warp/0.6.3
# ] startup
# [1.514s] [ext: omni.kit.property.usd-3.18.17] startup
# [1.521s] [ext: omni.kit.graph.delegate.modern-1.6.5] startup
# [1.522s] [ext: omni.graph.ui-1.24.2] startup
# [1.546s] [ext: omni.physics.tensors-0.1.0] startup
# [1.551s] [ext: omni.kit.graph.widget.variables-2.0.4] startup
# [1.552s] [ext: omni.kit.graph.usd.commands-1.2.0] startup
# [1.553s] [ext: omni.convexdecomposition-104.2.4-5.1] startup
# [1.554s] [ext: omni.graph.window.core-1.43.3] startup
# [1.560s] [ext: omni.kit.widget.zoombar-1.0.4] startup
# [1.561s] [ext: omni.kvdb-0.0.0] startup
# [1.562s] [ext: omni.usdphysics-104.2.4-5.1] startup
# [1.564s] [ext: omni.localcache-0.0.0] startup
# [1.565s] [ext: omni.graph.scriptnode-0.10.0] startup
# [1.567s] [ext: omni.physx-104.2.4-5.1] startup
# [1.605s] [ext: omni.command.usd-1.0.2] startup
# [1.608s] [ext: omni.physx.tensors-0.1.0] startup
# [1.612s] [ext: omni.graph.window.generic-1.3.15] startup
# [1.613s] [ext: omni.kit.browser.core-2.2.2] startup
# [1.616s] [ext: omni.graph.action-1.31.1] startup
# [1.622s] [ext: omni.kit.browser.folder.core-1.7.3] startup
# [1.624s] [ext: omni.kit.window.cursor-1.1.1] startup
# [1.624s] [ext: omni.kit.widget.spinner-1.0.4] startup
# [1.625s] [ext: omni.kit.browser.sample-1.2.5] startup
# [1.626s] [ext: omni.graph.nodes-1.48.3] startup
# [1.635s] [ext: omni.kit.viewport.menubar.core-104.4.3] startup
# [1.648s] [ext: omni.kit.numpy.common-0.1.0] startup
# [1.649s] [ext: omni.warp-0.6.3] startup
# [1.833s] [ext: omni.syntheticdata-0.2.4] startup
# 2023-06-21 19:04:47 [1,835ms] [Warning] [omni.kit.viewport.menubar.core.menu_item.viewport_menu_item] ViewportMenuItem order argument is deprecated, use order_setting_path
# [1.845s] [ext: omni.isaac.dynamic_control-1.2.3] startup
# [1.851s] [ext: omni.replicator.core-1.7.8] startup
# 2023-06-21 19:04:47 [1,896ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [1.998s] [ext: omni.isaac.core-1.46.3] startup
# [2.555s] [ext: omni.kit.manipulator.viewport-104.0.7] startup
# [2.556s] [ext: omni.isaac.core_nodes-0.23.2] startup
# [2.628s] [ext: omni.isaac.cloner-0.4.1] startup
# [2.629s] [ext: omni.isaac.lula-1.2.1] startup
# [2.635s] [ext: omni.graph.visualization.nodes-2.0.0] startup
# [2.640s] [ext: omni.isaac.debug_draw-0.2.3] startup
# [2.643s] [ext: omni.isaac.gym-0.3.3] startup
# [2.644s] [ext: omni.graph.window.action-1.5.5] startup
# [2.645s] [ext: omni.isaac.ui-0.8.0] startup
# [2.647s] [ext: usdrt.scenegraph-4.3.2] startup
# [2.660s] [ext: omni.isaac.motion_planning-0.2.2] startup
# [2.665s] [ext: omni.isaac.surface_gripper-0.4.0] startup
# [2.668s] [ext: omni.isaac.range_sensor-0.8.1] startup
# [2.690s] [ext: omni.isaac.motion_generation-4.5.6] startup
# [2.694s] [ext: omni.isaac.manipulators-1.1.0] startup
# [2.695s] [ext: omni.isaac.sensor-5.6.3] startup
# 2023-06-21 19:04:48 [2,689ms] [Warning] [omni.ext.plugin] [ext: omni.isaac.sensor-5.6.3] Native plugin search dir contains several files: /home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.isaac.sensor/bin . It makes dir walk slow, replace with the exact path to the plugin instead of a wildcard.
# [2.722s] [ext: omni.isaac.dofbot-0.3.0] startup
# [2.723s] [ext: omni.isaac.occupancy_map-0.2.7] startup
# [2.731s] [ext: omni.isaac.quadruped-1.3.0] startup
# [2.839s] [ext: omni.isaac.scene_blox-0.1.0] startup
# [2.840s] [ext: omni.isaac.synthetic_utils-0.4.3] startup
# [2.841s] [ext: omni.isaac.universal_robots-0.3.2] startup
# [2.842s] [ext: omni.isaac.isaac_sensor-2.0.0] startup
# 2023-06-21 19:04:48 [2,836ms] [Warning] [omni.isaac.isaac_sensor] omni.isaac.isaac_sensor is deprecated and was renamed; use omni.isaac.sensor
# [2.842s] [ext: omni.kit.widget.live_session_management-1.1.3] startup
# [2.844s] [ext: omni.kit.hotkeys.core-1.0.8] startup
# [2.849s] [ext: omni.isaac.wheeled_robots-0.6.3] startup
# [2.854s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [2.855s] [ext: omni.kit.widget.layers-1.6.11] startup
# [2.862s] [ext: omni.kit.selection-0.1.0] startup
# [2.864s] [ext: omni.isaac.mjcf-0.3.1] startup
# [2.869s] [ext: omni.kit.window.stage-2.3.12] startup
# [2.871s] [ext: omni.kit.property.layer-1.1.4] startup
# [2.873s] [ext: omni.kit.menu.edit-1.1.6] startup
# [2.874s] [ext: omni.kit.menu.file-1.1.4] startup
# [2.875s] [ext: omni.kit.menu.stage-1.2.1] startup
# [2.876s] [ext: omni.kit.property.audio-1.0.6] startup
# [2.877s] [ext: omni.kit.property.camera-1.0.3] startup
# [2.878s] [ext: omni.kit.property.geometry-1.2.2] startup
# [2.879s] [ext: omni.kit.property.light-1.0.6] startup
# [2.880s] [ext: omni.hydra.scene_api-0.1.1] startup
# [2.885s] [ext: omni.kit.property.material-1.8.19] startup
# [2.886s] [ext: omni.kit.property.render-1.1.0] startup
# [2.887s] [ext: omni.kit.property.skel-1.0.1] startup
# [2.888s] [ext: omni.kit.property.transform-1.3.5] startup
# [2.890s] [ext: omni.kit.manipulator.transform-104.6.12] startup
# [2.891s] [ext: omni.kit.widget.toolbar-1.4.0] startup
# [2.896s] [ext: omni.kit.profiler.window-2.0.5] startup
# [2.942s] [ext: omni.kit.property.bundle-1.2.6] startup
# [2.943s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [2.944s] [ext: omni.kit.manipulator.tool.snap-1.2.4] startup
# [2.948s] [ext: omni.kit.window.toolbar-1.4.0] startup
# [2.949s] [ext: omni.kit.property.isaac-0.2.0] startup
# [2.950s] [ext: omni.kit.stage_column.payload-1.0.8] startup
# [2.952s] [ext: omni.kit.manipulator.camera-104.0.23] startup
# [2.952s] [ext: omni.kit.manipulator.prim-104.10.7] startup
# [2.956s] [ext: omni.kit.manipulator.selection-104.0.6] startup
# [2.956s] [ext: omni.kit.viewport.menubar.display-104.1.11] startup
# [2.957s] [ext: omni.kit.viewport.menubar.camera-104.1.9] startup
# [2.960s] [ext: omni.rtx.window.settings-0.6.2] startup
# [2.964s] [ext: omni.kit.viewport.menubar.settings-104.3.5] startup
# [2.966s] [ext: omni.kit.viewport.menubar.render-104.0.20] startup
# [2.968s] [ext: omni.physx.commands-104.2.4-5.1] startup
# [2.972s] [ext: omni.kit.stage_column.variant-1.0.9] startup
# [2.972s] [ext: omni.hydra.pxr.settings-1.0.3] startup
# [2.973s] [ext: omni.kit.viewport.bundle-104.0.2] startup
# [2.973s] [ext: omni.physx.ui-104.2.4-5.1] startup
# [3.012s] [ext: omni.kit.viewport.menubar.lighting-104.0.9] startup
# [3.014s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [3.014s] [ext: omni.kit.viewport.ready-1.0.2] startup
# [3.015s] [ext: omni.physx.demos-104.2.4-5.1] startup
# [3.017s] [ext: omni.kit.property.physx-0.1.0] startup
# [3.049s] [ext: omni.isaac.urdf-0.5.9] startup
# [3.069s] [ext: omni.kit.widget.highlight_label-1.0.0] startup
# [3.070s] [ext: omni.physx.supportui-104.2.4-5.1] startup
# [3.164s] [ext: omni.physx.vehicle-104.2.4-5.1] startup
# [3.172s] [ext: omni.physx.cct-104.2.4-5.1] startup
# [3.178s] [ext: omni.physx.camera-104.2.4-5.1] startup
# [3.182s] [ext: omni.kit.actions.window-1.1.0] startup
# [3.185s] [ext: omni.kit.window.commands-0.2.4] startup
# [3.186s] [ext: omni.kit.window.console-0.2.3] startup
# [3.192s] [ext: omni.physx.bundle-104.2.4-5.1] startup
# [3.193s] [ext: omni.graph.bundle.action-1.3.0] startup
# [3.193s] [ext: omni.kit.window.script_editor-1.7.2] startup
# [3.194s] [ext: omni.kit.hotkeys.window-1.1.3] startup
# [3.198s] [ext: omni.kit.window.status_bar-0.1.5] startup
# [3.201s] [ext: omni.kit.window.title-1.1.2] startup
# [3.202s] [ext: omni.replicator.composer-1.2.10] startup
# [3.205s] [ext: omni.replicator.isaac-1.7.4] startup
# [3.215s] [ext: omni.resourcemonitor-1.0.0] startup
# [3.219s] [ext: omni.rtx.settings.core-0.5.8] startup
# [3.223s] [ext: omni.isaac.franka-0.4.0] startup
# [3.223s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [3.223s] [ext: semantics.schema.editor-0.3.3] startup
# [3.226s] [ext: omni.kit.widget.live-2.0.3] startup
# [3.227s] [ext: omni.isaac.utils-0.2.4] startup
# [3.230s] [ext: omni.isaac.kit-1.4.1] startup
# [3.230s] [ext: omni.isaac.cortex-0.3.2] startup
# [3.230s] [ext: omni.kit.window.stats-0.1.2] startup
# [3.231s] [ext: omni.isaac.sim.python-2022.2.1] startup
# [3.232s] Simulation App Starting
# Saving a temp livesync stage at  omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd  ...2023-06-21 19:04:49 [4,279ms] [Warning] [omni.usd] Default value for render setting "/rtx/shaderDb/cachePermutationIndex" not found
# 2023-06-21 19:04:49 [4,280ms] [Warning] [omni.usd] Default value for render setting "/rtx/pathtracing/nrc/canRun" not found
# 2023-06-21 19:04:49 [4,281ms] [Warning] [omni.usd] Default value for render setting "/rtx/multiThreading/enabled" not found
# 2023-06-21 19:04:49 [4,281ms] [Warning] [omni.usd] Default value for render setting "/rtx/hydra/mdlMaterialWarmup" not found
# Done.
# 2023-06-21 19:04:49 [4,292ms] [Error] [omni.usd] ERROR! Cannot save layer anon:0x1401c7c0:World0.usd to new path as new path omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd cannot be opened.
# 2023-06-21 19:04:49 [4,292ms] [Error] [omni.usd] Failed to save layer anon:0x1401c7c0:World0.usd to new path omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd

# %%
from omni.isaac.core import World
from omni.isaac.core.objects import DynamicCuboid
import numpy as np

# %%
world = World(stage_units_in_meters=1.0)
world.scene.add_default_ground_plane()
# A render/ step or an update call is needed to reflect the changes to the opened USD in Isaac Sim GUI
#  Note: avoid pressing play/ pause or stop in the GUI in this workflow.
world.render()

# %%
fancy_cube = world.scene.add(
    DynamicCuboid(
        prim_path="/World/random_cube",
        name="fancy_cube",
        position=np.array([0, 0, 1.000]),
        scale=np.array([0.5015, 0.505, 0.5015]),
        size=1.0,
        color=np.array([0, 0, 1.0]),
    )
)
world.render()

# %%
world.reset()
for i in range(500):
    position, orientation = fancy_cube.get_world_pose()
    linear_velocity = fancy_cube.get_linear_velocity()
    print("Cube position is : " + str(position))
    print("Cube's orientation is : " + str(orientation))
    print("Cube's linear velocity is : " + str(linear_velocity))
    # we have control over stepping physics and rendering in this workflow
    # things run in sync
    world.step(render=True)  # execute one physics step and one rendering step

# %%
# Cleanup application
simulation_app.close()
