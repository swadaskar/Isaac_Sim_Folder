# %%
# Copyright (c) 2020-2021, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.

# %% [markdown]
# # Create a Headless IsaacSim
#
# You should only have to do this part once; it will load kit, or at least the headless IsaacSim version of kit, by calling
# simulation_app = SimulationApp(CONFIG).This will take some time, so give it a minute and wait for it to say "Hi".

# %%
import getpass

user = getpass.getuser()
from omni.isaac.kit import SimulationApp

# Set the path below to your desired nucleus server
simulation_app = SimulationApp(
    {"headless": True, "livesync_usd": f"omniverse://localhost/Users/{user}/temp_jupyter_stage.usd"}
)
print("Hi")
# Out:
# Starting kit application with the following args:  ['/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts', '--ext-folder', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/apps', '--/physics/cudaDevice=0', '--portable', '--no-window']
# Passing the following args to the base kit application:  ['-f', '/home/lm-2023/.local/share/jupyter/runtime/kernel-2693d7e3-ba93-46a0-a163-48f122cdaec0.json']
# [Warning] [omni.isaac.kit.simulation_app] Modules: ['omni.isaac.kit.app_framework'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [omni.isaac.kit.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/logs/Kit/Isaac-Sim/2022.2/kit_20230621_121623.log
# 2023-06-21 19:16:23 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.lidar] Extensions config 'extension.toml' doesn't exist '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.lidar' or '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.lidar/config'
# 2023-06-21 19:16:23 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.radar] Extensions config 'extension.toml' doesn't exist '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.radar' or '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.radar/config'
# [0.167s] [ext: omni.stats-0.0.0] startup
# [0.189s] [ext: omni.rtx.shadercache-1.0.0] startup
# [0.192s] [ext: omni.assets.plugins-0.0.0] startup
# [0.193s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.197s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.202s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 530.30.02     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3080          | Yes: 0 |     | 10486   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2216      | acc370a7.. |
# |=============================================================================================|
# | OS: Linux lm2023-XPS-8950, Version: 5.15.0-75-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12013000 (1.20.13.0)
# | Processor: 12th Gen Intel(R) Core(TM) i7-12700 | Cores: Unknown | Logical: 20
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31816 | Free Memory: 23047
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# [0.704s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.708s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.710s] [ext: omni.kit.loop-isaac-1.0.0] startup
# [0.710s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.711s] [ext: omni.kit.test-0.0.0] startup
# [0.722s] [ext: omni.usd.config-1.0.0] startup
# [0.725s] [ext: omni.usd.libs-1.0.0] startup
# [0.826s] [ext: omni.isaac.core_archive-2.0.1] startup
# [0.880s] [ext: omni.pip.torch-1_13_1-0.1.4] startup
# [0.883s] [ext: omni.isaac.ml_archive-1.1.0] startup
# [0.914s] [ext: omni.client-0.1.1] startup
# [0.922s] [ext: omni.appwindow-1.0.1] startup
# [0.923s] [ext: omni.kit.renderer.core-0.0.0] startup
# [0.928s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.930s] [ext: omni.kit.renderer.imgui-0.0.0] startup
# [0.983s] [ext: carb.audio-0.1.0] startup
# [0.984s] [ext: omni.ui-2.14.4] startup
# [0.990s] [ext: omni.uiaudio-1.0.0] startup
# [0.991s] [ext: omni.kit.mainwindow-1.0.0] startup
# [0.992s] [ext: omni.kit.uiapp-0.0.0] startup
# [0.992s] [ext: omni.usd.schema.physics-1.0.0] startup
# [1.016s] [ext: omni.usd.schema.isaac-1.1.0] startup
# [1.025s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.031s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.036s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [1.040s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.045s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.049s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.084s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.087s] [ext: omni.usd.schema.scene.visualization-1.0.0] startup
# [1.088s] [ext: omni.usd.schema.physx-0.0.0] startup
# [1.105s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.105s] [ext: omni.timeline-1.0.5] startup
# [1.106s] [ext: omni.kit.search_core-1.0.2] startup
# [1.106s] [ext: omni.hydra.scene_delegate-0.3.0] startup
# [1.110s] [ext: omni.kit.widget.path_field-2.0.4] startup
# [1.113s] [ext: omni.kit.widget.filebrowser-2.3.10] startup
# [1.142s] [ext: omni.kit.widget.browser_bar-2.0.5] startup
# [1.142s] [ext: omni.kit.window.popup_dialog-2.0.16] startup
# [1.145s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.146s] [ext: omni.usd.core-1.0.4] startup
# [1.148s] [ext: omni.kit.audiodeviceenum-1.0.0] startup
# [1.149s] [ext: omni.kit.widget.nucleus_connector-1.0.3] startup
# [1.149s] [ext: omni.kit.commands-1.4.5] startup
# [1.152s] [ext: omni.hydra.usdrt_delegate-4.3.2] startup
# [1.163s] [ext: omni.kit.notification_manager-1.0.5] startup
# [1.164s] [ext: omni.usd-1.6.30] startup
# [1.193s] [ext: omni.kit.widget.versioning-1.3.8] startup
# [1.195s] [ext: omni.iray.libs-0.0.0] startup
# [1.197s] [ext: omni.kit.window.filepicker-2.7.15] startup
# [1.227s] [ext: omni.mdl.neuraylib-0.1.0] startup
# [1.229s] [ext: omni.kit.collaboration.channel_manager-1.0.9] startup
# [1.230s] [ext: omni.kit.window.file_importer-1.0.10] startup
# [1.230s] [ext: omni.mdl-0.1.0] startup
# [1.244s] [ext: omni.kit.usd.layers-2.0.11] startup
# [1.249s] [ext: omni.kit.menu.utils-1.4.7] startup
# [1.256s] [ext: omni.kit.material.library-1.3.21] startup
# [1.260s] [ext: omni.kit.menu.create-1.0.8] startup
# [1.260s] [ext: omni.kit.clipboard-1.0.0] startup
# [1.261s] [ext: omni.kit.widget.graph-1.5.6-104_2] startup
# [1.277s] [ext: omni.kit.context_menu-1.5.12] startup
# [1.279s] [ext: omni.kit.window.extensions-1.1.1] startup
# [1.282s] [ext: omni.inspect-1.0.1] startup
# [1.284s] [ext: omni.kit.window.property-1.8.2] startup
# [1.286s] [ext: omni.kit.primitive.mesh-1.0.8] startup
# [1.288s] [ext: omni.graph.core-2.65.4] startup
# [1.290s] [ext: omni.isaac.version-1.0.0] startup
# [1.290s] [ext: omni.kit.stage_templates-1.1.13] startup
# [1.292s] [ext: omni.kit.usd_undo-0.1.2] startup
# [1.292s] [ext: omni.graph.tools-1.17.2] startup
# [1.303s] [ext: omni.ui.scene-1.5.18] startup
# [1.306s] [ext: omni.graph-1.50.2] startup
# [1.365s] [ext: omni.ui_query-1.1.1] startup
# [1.366s] [ext: omni.volume-0.1.0] startup
# [1.368s] [ext: omni.kit.ui_test-1.2.9] startup
# [1.369s] [ext: omni.hydra.rtx-0.1.0] startup
# [1.373s] [ext: omni.kit.widget.searchfield-1.0.10] startup
# [1.374s] [ext: omni.kit.graph.delegate.default-1.0.18] startup
# [1.375s] [ext: omni.debugdraw-0.1.1] startup
# [1.378s] [ext: omni.kit.graph.editor.core-1.4.7] startup
# [1.379s] [ext: omni.hydra.pxr-1.1.2] startup
# [1.383s] [ext: omni.activity.core-1.0.1] startup
# [1.385s] [ext: omni.kit.hydra_texture-1.0.11] startup
# [1.388s] [ext: omni.kit.viewport.legacy_gizmos-1.0.10] startup
# [1.391s] [ext: omni.kit.viewport.registry-104.0.2] startup
# [1.392s] [ext: omni.kit.widget.viewport-104.1.16] startup
# [1.393s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [1.394s] [ext: omni.kit.window.file_exporter-1.0.10] startup
# [1.394s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [1.396s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [1.397s] [ext: omni.kit.window.file-1.3.32] startup
# [1.399s] [ext: omni.kit.viewport.window-104.1.23] startup
# 2023-06-21 19:16:25 [1,389ms] [Warning] [omni.kit.ui.editor_menu] set_value menu Window/Viewport/Viewport 1 not found
# [1.416s] [ext: omni.kit.widget.settings-1.0.1] startup
# [1.417s] [ext: omni.kit.widget.stage-2.7.24] startup
# [1.420s] [ext: omni.kit.window.content_browser-2.6.8] startup
# [1.428s] [ext: omni.kit.viewport.utility-1.0.14] startup
# [1.428s] [ext: omni.kit.window.preferences-1.3.8] startup
# [1.447s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [1.448s] [ext: omni.kit.widget.prompt-1.0.5Warp 0.6.3 initialized:
#    CUDA Toolkit: 11.5, Driver: 12.1
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA GeForce RTX 3080 (sm_86)
#    Kernel cache: /home/lm-2023/.cache/warp/0.6.3
# ] startup
# [1.449s] [ext: omni.kit.property.usd-3.18.17] startup
# [1.457s] [ext: omni.kit.graph.delegate.modern-1.6.5] startup
# [1.458s] [ext: omni.graph.ui-1.24.2] startup
# [1.482s] [ext: omni.physics.tensors-0.1.0] startup
# [1.488s] [ext: omni.kit.graph.widget.variables-2.0.4] startup
# [1.489s] [ext: omni.kit.graph.usd.commands-1.2.0] startup
# [1.490s] [ext: omni.convexdecomposition-104.2.4-5.1] startup
# [1.491s] [ext: omni.graph.window.core-1.43.3] startup
# [1.497s] [ext: omni.kit.widget.zoombar-1.0.4] startup
# [1.497s] [ext: omni.kvdb-0.0.0] startup
# [1.499s] [ext: omni.usdphysics-104.2.4-5.1] startup
# [1.500s] [ext: omni.localcache-0.0.0] startup
# [1.502s] [ext: omni.graph.scriptnode-0.10.0] startup
# [1.503s] [ext: omni.physx-104.2.4-5.1] startup
# [1.542s] [ext: omni.command.usd-1.0.2] startup
# [1.547s] [ext: omni.physx.tensors-0.1.0] startup
# [1.552s] [ext: omni.graph.window.generic-1.3.15] startup
# [1.554s] [ext: omni.kit.browser.core-2.2.2] startup
# [1.557s] [ext: omni.graph.action-1.31.1] startup
# [1.562s] [ext: omni.kit.browser.folder.core-1.7.3] startup
# [1.564s] [ext: omni.kit.window.cursor-1.1.1] startup
# [1.565s] [ext: omni.kit.widget.spinner-1.0.4] startup
# [1.566s] [ext: omni.kit.browser.sample-1.2.5] startup
# [1.567s] [ext: omni.graph.nodes-1.48.3] startup
# [1.575s] [ext: omni.kit.viewport.menubar.core-104.4.3] startup
# [1.587s] [ext: omni.kit.numpy.common-0.1.0] startup
# [1.589s] [ext: omni.warp-0.6.3] startup
# [1.768s] [ext: omni.syntheticdata-0.2.4] startup
# 2023-06-21 19:16:25 [1,764ms] [Warning] [omni.kit.viewport.menubar.core.menu_item.viewport_menu_item] ViewportMenuItem order argument is deprecated, use order_setting_path
# [1.779s] [ext: omni.isaac.dynamic_control-1.2.3] startup
# [1.785s] [ext: omni.replicator.core-1.7.8] startup
# 2023-06-21 19:16:25 [1,823ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [1.911s] [ext: omni.isaac.core-1.46.3] startup
# [2.452s] [ext: omni.kit.manipulator.viewport-104.0.7] startup
# [2.453s] [ext: omni.isaac.core_nodes-0.23.2] startup
# [2.522s] [ext: omni.isaac.cloner-0.4.1] startup
# [2.523s] [ext: omni.isaac.lula-1.2.1] startup
# [2.529s] [ext: omni.graph.visualization.nodes-2.0.0] startup
# [2.534s] [ext: omni.isaac.debug_draw-0.2.3] startup
# [2.537s] [ext: omni.isaac.gym-0.3.3] startup
# [2.538s] [ext: omni.graph.window.action-1.5.5] startup
# [2.538s] [ext: omni.isaac.ui-0.8.0] startup
# [2.540s] [ext: usdrt.scenegraph-4.3.2] startup
# [2.553s] [ext: omni.isaac.motion_planning-0.2.2] startup
# [2.558s] [ext: omni.isaac.surface_gripper-0.4.0] startup
# [2.562s] [ext: omni.isaac.range_sensor-0.8.1] startup
# [2.583s] [ext: omni.isaac.motion_generation-4.5.6] startup
# [2.587s] [ext: omni.isaac.manipulators-1.1.0] startup
# [2.588s] [ext: omni.isaac.sensor-5.6.3] startup
# 2023-06-21 19:16:26 [2,577ms] [Warning] [omni.ext.plugin] [ext: omni.isaac.sensor-5.6.3] Native plugin search dir contains several files: /home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.isaac.sensor/bin . It makes dir walk slow, replace with the exact path to the plugin instead of a wildcard.
# [2.614s] [ext: omni.isaac.dofbot-0.3.0] startup
# [2.614s] [ext: omni.isaac.occupancy_map-0.2.7] startup
# [2.623s] [ext: omni.isaac.quadruped-1.3.0] startup
# [2.741s] [ext: omni.isaac.scene_blox-0.1.0] startup
# [2.742s] [ext: omni.isaac.synthetic_utils-0.4.3] startup
# [2.743s] [ext: omni.isaac.universal_robots-0.3.2] startup
# [2.743s] [ext: omni.isaac.isaac_sensor-2.0.0] startup
# 2023-06-21 19:16:26 [2,732ms] [Warning] [omni.isaac.isaac_sensor] omni.isaac.isaac_sensor is deprecated and was renamed; use omni.isaac.sensor
# [2.744s] [ext: omni.kit.widget.live_session_management-1.1.3] startup
# [2.746s] [ext: omni.kit.hotkeys.core-1.0.8] startup
# [2.750s] [ext: omni.isaac.wheeled_robots-0.6.3] startup
# [2.755s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [2.756s] [ext: omni.kit.widget.layers-1.6.11] startup
# [2.763s] [ext: omni.kit.selection-0.1.0] startup
# [2.764s] [ext: omni.isaac.mjcf-0.3.1] startup
# [2.769s] [ext: omni.kit.window.stage-2.3.12] startup
# [2.771s] [ext: omni.kit.property.layer-1.1.4] startup
# [2.773s] [ext: omni.kit.menu.edit-1.1.6] startup
# [2.774s] [ext: omni.kit.menu.file-1.1.4] startup
# [2.775s] [ext: omni.kit.menu.stage-1.2.1] startup
# [2.776s] [ext: omni.kit.property.audio-1.0.6] startup
# [2.777s] [ext: omni.kit.property.camera-1.0.3] startup
# [2.777s] [ext: omni.kit.property.geometry-1.2.2] startup
# [2.779s] [ext: omni.kit.property.light-1.0.6] startup
# [2.780s] [ext: omni.hydra.scene_api-0.1.1] startup
# [2.785s] [ext: omni.kit.property.material-1.8.19] startup
# [2.786s] [ext: omni.kit.property.render-1.1.0] startup
# [2.787s] [ext: omni.kit.property.skel-1.0.1] startup
# [2.788s] [ext: omni.kit.property.transform-1.3.5] startup
# [2.790s] [ext: omni.kit.manipulator.transform-104.6.12] startup
# [2.791s] [ext: omni.kit.widget.toolbar-1.4.0] startup
# [2.795s] [ext: omni.kit.profiler.window-2.0.5] startup
# [2.840s] [ext: omni.kit.property.bundle-1.2.6] startup
# [2.841s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [2.841s] [ext: omni.kit.manipulator.tool.snap-1.2.4] startup
# [2.845s] [ext: omni.kit.window.toolbar-1.4.0] startup
# [2.847s] [ext: omni.kit.property.isaac-0.2.0] startup
# [2.848s] [ext: omni.kit.stage_column.payload-1.0.8] startup
# [2.849s] [ext: omni.kit.manipulator.camera-104.0.23] startup
# [2.849s] [ext: omni.kit.manipulator.prim-104.10.7] startup
# [2.853s] [ext: omni.kit.manipulator.selection-104.0.6] startup
# [2.853s] [ext: omni.kit.viewport.menubar.display-104.1.11] startup
# [2.854s] [ext: omni.kit.viewport.menubar.camera-104.1.9] startup
# [2.857s] [ext: omni.rtx.window.settings-0.6.2] startup
# [2.860s] [ext: omni.kit.viewport.menubar.settings-104.3.5] startup
# [2.863s] [ext: omni.kit.viewport.menubar.render-104.0.20] startup
# [2.864s] [ext: omni.physx.commands-104.2.4-5.1] startup
# [2.867s] [ext: omni.kit.stage_column.variant-1.0.9] startup
# [2.868s] [ext: omni.hydra.pxr.settings-1.0.3] startup
# [2.869s] [ext: omni.kit.viewport.bundle-104.0.2] startup
# [2.869s] [ext: omni.physx.ui-104.2.4-5.1] startup
# [2.906s] [ext: omni.kit.viewport.menubar.lighting-104.0.9] startup
# [2.907s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [2.907s] [ext: omni.kit.viewport.ready-1.0.2] startup
# [2.908s] [ext: omni.physx.demos-104.2.4-5.1] startup
# [2.910s] [ext: omni.kit.property.physx-0.1.0] startup
# [2.940s] [ext: omni.isaac.urdf-0.5.9] startup
# [2.960s] [ext: omni.kit.widget.highlight_label-1.0.0] startup
# [2.961s] [ext: omni.physx.supportui-104.2.4-5.1] startup
# [3.047s] [ext: omni.physx.vehicle-104.2.4-5.1] startup
# [3.055s] [ext: omni.physx.cct-104.2.4-5.1] startup
# [3.060s] [ext: omni.physx.camera-104.2.4-5.1] startup
# [3.064s] [ext: omni.kit.actions.window-1.1.0] startup
# [3.068s] [ext: omni.kit.window.commands-0.2.4] startup
# [3.069s] [ext: omni.kit.window.console-0.2.3] startup
# [3.074s] [ext: omni.physx.bundle-104.2.4-5.1] startup
# [3.075s] [ext: omni.graph.bundle.action-1.3.0] startup
# [3.075s] [ext: omni.kit.window.script_editor-1.7.2] startup
# [3.076s] [ext: omni.kit.hotkeys.window-1.1.3] startup
# [3.079s] [ext: omni.kit.window.status_bar-0.1.5] startup
# [3.082s] [ext: omni.kit.window.title-1.1.2] startup
# [3.083s] [ext: omni.replicator.composer-1.2.10] startup
# [3.085s] [ext: omni.replicator.isaac-1.7.4] startup
# [3.095s] [ext: omni.resourcemonitor-1.0.0] startup
# [3.099s] [ext: omni.rtx.settings.core-0.5.8] startup
# [3.102s] [ext: omni.isaac.franka-0.4.0] startup
# [3.103s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [3.103s] [ext: semantics.schema.editor-0.3.3] startup
# [3.105s] [ext: omni.kit.widget.live-2.0.3] startup
# [3.106s] [ext: omni.isaac.utils-0.2.4] startup
# [3.109s] [ext: omni.isaac.kit-1.4.1] startup
# [3.109s] [ext: omni.isaac.cortex-0.3.2] startup
# [3.109s] [ext: omni.kit.window.stats-0.1.2] startup
# [3.110s] [ext: omni.isaac.sim.python-2022.2.1] startup
# [3.111s] Simulation App Starting
# Saving a temp livesync stage at  omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd  ...2023-06-21 19:16:28 [4,140ms] [Warning] [omni.usd] Default value for render setting "/rtx/shaderDb/cachePermutationIndex" not found
# 2023-06-21 19:16:28 [4,140ms] [Warning] [omni.usd] Default value for render setting "/rtx/pathtracing/nrc/canRun" not found
# 2023-06-21 19:16:28 [4,142ms] [Warning] [omni.usd] Default value for render setting "/rtx/multiThreading/enabled" not found
# 2023-06-21 19:16:28 [4,142ms] [Warning] [omni.usd] Default value for render setting "/rtx/hydra/mdlMaterialWarmup" not found
# 2023-06-21 19:16:28 [4,151ms] [Warning] [omni.client.plugin]  Tick: authentication: Discovery(ws://localhost:3333): Error creating Api/Connection search: Not connected
# Done.
# 2023-06-21 19:16:28 [4,152ms] [Error] [omni.usd] ERROR! Cannot save layer anon:0x14817320:World0.usd to new path as new path omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd cannot be opened.
# 2023-06-21 19:16:28 [4,152ms] [Error] [omni.usd] Failed to save layer anon:0x14817320:World0.usd to new path omniverse://localhost/Users/lm-2023/temp_jupyter_stage.usd
# Hi

# %% [markdown]
# # Iterative Development
#
# Once `simulation_app` is up and running in your notebook, the iterative development process begins. The iterative development process consists of creating a scene, or stage in usd lingo, and then viewing and interacting with it. There are two ways to view and interact with your stage; with `simulation_app` in this python notebook, or with an external Omniverse viewer, like vanilla Kit or IsaacSim. To use the external viewer, just open the `livesync_usd` file and make sure live update is on the root layer
#
# ## Create a simulation context and move camera
#
# Here we create a `SimulationContext` object which provides a high level interface to interact with the simulation

# %%
from omni.isaac.core import World
from omni.isaac.core.utils.prims import create_prim
from omni.isaac.core.utils.viewports import set_camera_view
from omni.isaac.core.utils.nucleus import get_assets_root_path
from omni.isaac.core.materials.omni_glass import OmniGlass
from omni.isaac.core.prims.xform_prim import XFormPrim
from omni.isaac.core.utils.extensions import get_extension_path_from_name
from omni.isaac.core.utils.semantics import add_update_semantics

import omni
import carb
import numpy as np

simulation_world = World(stage_units_in_meters=1.0)
set_camera_view(eye=np.array([-0.9025, 2.1035, 1.0222]), target=np.array([0.6039, 0.30, 0.0950]))

# Step our simulation to ensure everything initialized
simulation_world.step()

# %% [markdown]
# ## Creating the scene
#
# Re-run the cell below to randomize the scene from scratch. The goal here is to make iterating on scene setup easy and not require restarts of the omniverse application.

# %%
# Delete everything in the stage
simulation_world.clear()
# SCENE SETUP

# Add a distant light
create_prim("/DistantLight", "DistantLight", attributes={"intensity": 500})

# Add a ground collision plane
simulation_world.scene.add_ground_plane(size=1000, z_position=-0.5, color=np.array([1, 1, 1]))

# Load a URDF
status, import_config = omni.kit.commands.execute("URDFCreateImportConfig")
import_config.merge_fixed_joints = False
import_config.convex_decomp = False
import_config.import_inertia_tensor = True
import_config.fix_base = False
import_config.distance_scale = 1.0
import_config.create_physics_scene = False  # we already have a physics scene from simulation_world

# Get path to extension data:
extension_path = get_extension_path_from_name("omni.isaac.urdf")
# Import URDF, stage_path contains the path the path to the usd prim in the stage.
status, stage_path = omni.kit.commands.execute(
    "URDFParseAndImportFile",
    urdf_path=extension_path + "/data/urdf/robots/carter/urdf/carter.urdf",
    import_config=import_config,
)
stage = simulation_world.stage
add_update_semantics(stage.GetPrimAtPath(stage_path), "Robot")

# Load a mesh
assets_root_path = get_assets_root_path()
if assets_root_path is None:
    carb.log_error("Could not find Isaac Sim assets folder")
usd_path = assets_root_path + "/Isaac/Props/YCB/Axis_Aligned/006_mustard_bottle.usd"

prim = create_prim(prim_path="/Mesh", usd_path=usd_path, scale=np.array([10.0, 10.0, 10.0]), semantic_label="mustard")
xform_prim = XFormPrim(prim.GetPath())


# Apply a glass material to mesh
material = OmniGlass(
    "/Looks/GlassMaterial", name="glass_material", ior=1.25, depth=0.001, thin_walled=False, color=np.random.rand(3)
)
xform_prim.apply_visual_material(material)

# Set mesh transform
xform_prim.set_world_pose(position=np.array([1.00, 0, 0]))

# %% [markdown]
# ## Viewing the scene in the notebook
#
# This next example does not change the scene (but it could if you used commands like the ones above), but it does use the IsaacSim's `SyntheticDataHelper` to view the data. Specifically, it shows a color, depth, and segmentation view of the scene, and then displays them within the notebook.

# %%
import matplotlib.pyplot as plt
from omni.syntheticdata import visualize
from omni.kit.viewport.utility import get_active_viewport
import omni.replicator.core as rep

viewport_api = get_active_viewport()
active_cam = viewport_api.get_active_camera()
resolution = viewport_api.get_texture_resolution()
render_product = rep.create.render_product(active_cam, resolution)

rgb = rep.AnnotatorRegistry.get_annotator("rgb")
rgb.attach([render_product])
depth = rep.AnnotatorRegistry.get_annotator("distance_to_image_plane")
depth.attach([render_product])
semantic_segmentation = rep.AnnotatorRegistry.get_annotator("semantic_segmentation")
semantic_segmentation.attach([render_product])

# Run the application for multiple frames to ensure the synthetic data pipeline is initialized
timeline = omni.timeline.get_timeline_interface()
timeline.play()
for _ in range(10):
    simulation_app.update()
timeline.pause()

# Get groundtruth
rgb_data = rgb.get_data()
depth_data = depth.get_data()
semantic_segmentation_data = semantic_segmentation.get_data()

# GROUNDTRUTH VISUALIZATION
# Setup a figure
_, axes = plt.subplots(1, 3, figsize=(20, 7))
axes = axes.flat
for ax in axes:
    ax.axis("off")

# RGB
axes[0].set_title("RGB")
axes[0].imshow(rgb_data)

# DEPTH
axes[1].set_title("Depth")
depth_data_clipped = np.clip(depth_data, 0, 255)
axes[1].imshow(visualize.colorize_distance(depth_data.squeeze()))

# SEMANTIC SEGMENTATION
axes[2].set_title("Semantic Segmentation")
# Draw the segmentation mask on top of the color image with a transparency
axes[2].imshow(rgb_data)
semantic_segmentation_rgb = visualize.colorize_segmentation(semantic_segmentation_data["data"])
axes[2].imshow(semantic_segmentation_rgb, alpha=0.7)

# %%
# Cleanup application
simulation_app.close()
