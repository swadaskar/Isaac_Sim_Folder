# %%
# Copyright (c) 2020-2021, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.

# %% [markdown]
# # Create a Headless IsaacSim
#
# You should only have to do this part once; it will load kit, or at least the headless IsaacSim version of kit, by calling
# simulation_app = SimulationApp(CONFIG).This will take some time, so give it a minute and wait for it to say "Hi".

# %%
import getpass

user = getpass.getuser()
from omni.isaac.kit import SimulationApp

# Set the path below to your desired nucleus server
simulation_app = SimulationApp(
    {"headless": True, "livesync_usd": f"omniverse://localhost/Users/{user}/.local/share/ov/data/temp_jupyter_stage.usd"}
)
print("Hi")
# Out:
# Starting kit application with the following args:  ['/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts', '--ext-folder', '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/apps', '--/physics/cudaDevice=0', '--portable', '--no-window']
# Passing the following args to the base kit application:  ['-f', '/home/lm-2023/.local/share/jupyter/runtime/kernel-4a28766e-450a-4e26-9885-4f47a83853fd.json']
# [Warning] [omni.isaac.kit.simulation_app] Modules: ['omni.isaac.kit.app_framework'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [omni.isaac.kit.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/logs/Kit/Isaac-Sim/2022.2/kit_20230621_122517.log
# 2023-06-21 19:25:17 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.lidar] Extensions config 'extension.toml' doesn't exist '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.lidar' or '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.lidar/config'
# 2023-06-21 19:25:17 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.radar] Extensions config 'extension.toml' doesn't exist '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.radar' or '/home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.sensors.nv.radar/config'
# [0.151s] [ext: omni.stats-0.0.0] startup
# [0.172s] [ext: omni.rtx.shadercache-1.0.0] startup
# [0.176s] [ext: omni.assets.plugins-0.0.0] startup
# [0.177s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.181s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.186s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 530.30.02     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3080          | Yes: 0 |     | 10486   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2216      | acc370a7.. |
# |=============================================================================================|
# | OS: Linux lm2023-XPS-8950, Version: 5.15.0-75-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12013000 (1.20.13.0)
# | Processor: 12th Gen Intel(R) Core(TM) i7-12700 | Cores: Unknown | Logical: 20
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31816 | Free Memory: 24111
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# [0.705s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.710s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.711s] [ext: omni.kit.loop-isaac-1.0.0] startup
# [0.712s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.712s] [ext: omni.kit.test-0.0.0] startup
# [0.724s] [ext: omni.usd.config-1.0.0] startup
# [0.727s] [ext: omni.usd.libs-1.0.0] startup
# [0.823s] [ext: omni.isaac.core_archive-2.0.1] startup
# [0.895s] [ext: omni.pip.torch-1_13_1-0.1.4] startup
# [0.897s] [ext: omni.isaac.ml_archive-1.1.0] startup
# [0.929s] [ext: omni.client-0.1.1] startup
# [0.936s] [ext: omni.appwindow-1.0.1] startup
# [0.938s] [ext: omni.kit.renderer.core-0.0.0] startup
# [0.944s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.946s] [ext: omni.kit.renderer.imgui-0.0.0] startup
# [0.990s] [ext: carb.audio-0.1.0] startup
# [1.009s] [ext: omni.ui-2.14.4] startup
# [1.015s] [ext: omni.uiaudio-1.0.0] startup
# [1.016s] [ext: omni.kit.mainwindow-1.0.0] startup
# [1.017s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.017s] [ext: omni.usd.schema.physics-1.0.0] startup
# [1.041s] [ext: omni.usd.schema.isaac-1.1.0] startup
# [1.050s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.056s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.061s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [1.066s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.071s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.075s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.109s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.113s] [ext: omni.usd.schema.scene.visualization-1.0.0] startup
# [1.114s] [ext: omni.usd.schema.physx-0.0.0] startup
# [1.130s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.130s] [ext: omni.timeline-1.0.5] startup
# [1.131s] [ext: omni.kit.search_core-1.0.2] startup
# [1.132s] [ext: omni.hydra.scene_delegate-0.3.0] startup
# [1.135s] [ext: omni.kit.widget.path_field-2.0.4] startup
# [1.138s] [ext: omni.kit.widget.filebrowser-2.3.10] startup
# [1.165s] [ext: omni.kit.widget.browser_bar-2.0.5] startup
# [1.166s] [ext: omni.kit.window.popup_dialog-2.0.16] startup
# [1.169s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.170s] [ext: omni.usd.core-1.0.4] startup
# [1.172s] [ext: omni.kit.audiodeviceenum-1.0.0] startup
# [1.172s] [ext: omni.kit.widget.nucleus_connector-1.0.3] startup
# [1.173s] [ext: omni.kit.commands-1.4.5] startup
# [1.176s] [ext: omni.hydra.usdrt_delegate-4.3.2] startup
# [1.186s] [ext: omni.kit.notification_manager-1.0.5] startup
# [1.188s] [ext: omni.usd-1.6.30] startup
# [1.216s] [ext: omni.kit.widget.versioning-1.3.8] startup
# [1.217s] [ext: omni.iray.libs-0.0.0] startup
# [1.220s] [ext: omni.kit.window.filepicker-2.7.15] startup
# [1.248s] [ext: omni.mdl.neuraylib-0.1.0] startup
# [1.250s] [ext: omni.kit.collaboration.channel_manager-1.0.9] startup
# [1.251s] [ext: omni.kit.window.file_importer-1.0.10] startup
# [1.252s] [ext: omni.mdl-0.1.0] startup
# [1.265s] [ext: omni.kit.usd.layers-2.0.11] startup
# [1.271s] [ext: omni.kit.menu.utils-1.4.7] startup
# [1.278s] [ext: omni.kit.material.library-1.3.21] startup
# [1.281s] [ext: omni.kit.menu.create-1.0.8] startup
# [1.282s] [ext: omni.kit.clipboard-1.0.0] startup
# [1.283s] [ext: omni.kit.widget.graph-1.5.6-104_2] startup
# [1.299s] [ext: omni.kit.context_menu-1.5.12] startup
# [1.301s] [ext: omni.kit.window.extensions-1.1.1] startup
# [1.304s] [ext: omni.inspect-1.0.1] startup
# [1.306s] [ext: omni.kit.window.property-1.8.2] startup
# [1.307s] [ext: omni.kit.primitive.mesh-1.0.8] startup
# [1.310s] [ext: omni.graph.core-2.65.4] startup
# [1.312s] [ext: omni.isaac.version-1.0.0] startup
# [1.312s] [ext: omni.kit.stage_templates-1.1.13] startup
# [1.314s] [ext: omni.kit.usd_undo-0.1.2] startup
# [1.314s] [ext: omni.graph.tools-1.17.2] startup
# [1.325s] [ext: omni.ui.scene-1.5.18] startup
# [1.328s] [ext: omni.graph-1.50.2] startup
# [1.388s] [ext: omni.ui_query-1.1.1] startup
# [1.389s] [ext: omni.volume-0.1.0] startup
# [1.391s] [ext: omni.kit.ui_test-1.2.9] startup
# [1.392s] [ext: omni.hydra.rtx-0.1.0] startup
# [1.396s] [ext: omni.kit.widget.searchfield-1.0.10] startup
# [1.397s] [ext: omni.kit.graph.delegate.default-1.0.18] startup
# [1.399s] [ext: omni.debugdraw-0.1.1] startup
# [1.402s] [ext: omni.kit.graph.editor.core-1.4.7] startup
# [1.403s] [ext: omni.hydra.pxr-1.1.2] startup
# [1.407s] [ext: omni.activity.core-1.0.1] startup
# [1.409s] [ext: omni.kit.hydra_texture-1.0.11] startup
# [1.412s] [ext: omni.kit.viewport.legacy_gizmos-1.0.10] startup
# [1.415s] [ext: omni.kit.viewport.registry-104.0.2] startup
# [1.416s] [ext: omni.kit.widget.viewport-104.1.16] startup
# [1.418s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [1.418s] [ext: omni.kit.window.file_exporter-1.0.10] startup
# [1.419s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [1.421s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [1.421s] [ext: omni.kit.window.file-1.3.32] startup
# [1.423s] [ext: omni.kit.viewport.window-104.1.23] startup
# 2023-06-21 19:25:19 [1,419ms] [Warning] [omni.kit.ui.editor_menu] set_value menu Window/Viewport/Viewport 1 not found
# [1.441s] [ext: omni.kit.widget.settings-1.0.1] startup
# [1.442s] [ext: omni.kit.widget.stage-2.7.24] startup
# [1.445s] [ext: omni.kit.window.content_browser-2.6.8] startup
# [1.453s] [ext: omni.kit.viewport.utility-1.0.14] startup
# [1.454s] [ext: omni.kit.window.preferences-1.3.8] startup
# [1.473s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [1.475s] [ext: omni.kit.widget.prompt-1.0.5Warp 0.6.3 initialized:
#    CUDA Toolkit: 11.5, Driver: 12.1
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA GeForce RTX 3080 (sm_86)
#    Kernel cache: /home/lm-2023/.cache/warp/0.6.3
# ] startup
# [1.476s] [ext: omni.kit.property.usd-3.18.17] startup
# [1.483s] [ext: omni.kit.graph.delegate.modern-1.6.5] startup
# [1.484s] [ext: omni.graph.ui-1.24.2] startup
# [1.507s] [ext: omni.physics.tensors-0.1.0] startup
# [1.512s] [ext: omni.kit.graph.widget.variables-2.0.4] startup
# [1.513s] [ext: omni.kit.graph.usd.commands-1.2.0] startup
# [1.514s] [ext: omni.convexdecomposition-104.2.4-5.1] startup
# [1.515s] [ext: omni.graph.window.core-1.43.3] startup
# [1.521s] [ext: omni.kit.widget.zoombar-1.0.4] startup
# [1.522s] [ext: omni.kvdb-0.0.0] startup
# [1.524s] [ext: omni.usdphysics-104.2.4-5.1] startup
# [1.525s] [ext: omni.localcache-0.0.0] startup
# [1.527s] [ext: omni.graph.scriptnode-0.10.0] startup
# [1.528s] [ext: omni.physx-104.2.4-5.1] startup
# [1.567s] [ext: omni.command.usd-1.0.2] startup
# [1.571s] [ext: omni.physx.tensors-0.1.0] startup
# [1.577s] [ext: omni.graph.window.generic-1.3.15] startup
# [1.578s] [ext: omni.kit.browser.core-2.2.2] startup
# [1.581s] [ext: omni.graph.action-1.31.1] startup
# [1.586s] [ext: omni.kit.browser.folder.core-1.7.3] startup
# [1.588s] [ext: omni.kit.window.cursor-1.1.1] startup
# [1.589s] [ext: omni.kit.widget.spinner-1.0.4] startup
# [1.590s] [ext: omni.kit.browser.sample-1.2.5] startup
# [1.591s] [ext: omni.graph.nodes-1.48.3] startup
# [1.599s] [ext: omni.kit.viewport.menubar.core-104.4.3] startup
# [1.611s] [ext: omni.kit.numpy.common-0.1.0] startup
# [1.613s] [ext: omni.warp-0.6.3] startup
# [1.786s] [ext: omni.syntheticdata-0.2.4] startup
# 2023-06-21 19:25:19 [1,787ms] [Warning] [omni.kit.viewport.menubar.core.menu_item.viewport_menu_item] ViewportMenuItem order argument is deprecated, use order_setting_path
# [1.797s] [ext: omni.isaac.dynamic_control-1.2.3] startup
# [1.803s] [ext: omni.replicator.core-1.7.8] startup
# 2023-06-21 19:25:19 [1,845ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [1.929s] [ext: omni.isaac.core-1.46.3] startup
# [2.459s] [ext: omni.kit.manipulator.viewport-104.0.7] startup
# [2.460s] [ext: omni.isaac.core_nodes-0.23.2] startup
# [2.531s] [ext: omni.isaac.cloner-0.4.1] startup
# [2.531s] [ext: omni.isaac.lula-1.2.1] startup
# [2.538s] [ext: omni.graph.visualization.nodes-2.0.0] startup
# [2.542s] [ext: omni.isaac.debug_draw-0.2.3] startup
# [2.546s] [ext: omni.isaac.gym-0.3.3] startup
# [2.546s] [ext: omni.graph.window.action-1.5.5] startup
# [2.547s] [ext: omni.isaac.ui-0.8.0] startup
# [2.549s] [ext: usdrt.scenegraph-4.3.2] startup
# [2.562s] [ext: omni.isaac.motion_planning-0.2.2] startup
# [2.567s] [ext: omni.isaac.surface_gripper-0.4.0] startup
# [2.570s] [ext: omni.isaac.range_sensor-0.8.1] startup
# [2.591s] [ext: omni.isaac.motion_generation-4.5.6] startup
# [2.596s] [ext: omni.isaac.manipulators-1.1.0] startup
# [2.597s] [ext: omni.isaac.sensor-5.6.3] startup
# 2023-06-21 19:25:20 [2,590ms] [Warning] [omni.ext.plugin] [ext: omni.isaac.sensor-5.6.3] Native plugin search dir contains several files: /home/lm-2023/.local/share/ov/pkg/isaac_sim-2022.2.1/exts/omni.isaac.sensor/bin . It makes dir walk slow, replace with the exact path to the plugin instead of a wildcard.
# [2.623s] [ext: omni.isaac.dofbot-0.3.0] startup
# [2.623s] [ext: omni.isaac.occupancy_map-0.2.7] startup
# [2.632s] [ext: omni.isaac.quadruped-1.3.0] startup
# [2.748s] [ext: omni.isaac.scene_blox-0.1.0] startup
# [2.748s] [ext: omni.isaac.synthetic_utils-0.4.3] startup
# [2.749s] [ext: omni.isaac.universal_robots-0.3.2] startup
# [2.750s] [ext: omni.isaac.isaac_sensor-2.0.0] startup
# 2023-06-21 19:25:20 [2,743ms] [Warning] [omni.isaac.isaac_sensor] omni.isaac.isaac_sensor is deprecated and was renamed; use omni.isaac.sensor
# [2.750s] [ext: omni.kit.widget.live_session_management-1.1.3] startup
# [2.752s] [ext: omni.kit.hotkeys.core-1.0.8] startup
# [2.757s] [ext: omni.isaac.wheeled_robots-0.6.3] startup
# [2.762s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [2.762s] [ext: omni.kit.widget.layers-1.6.11] startup
# [2.769s] [ext: omni.kit.selection-0.1.0] startup
# [2.770s] [ext: omni.isaac.mjcf-0.3.1] startup
# [2.776s] [ext: omni.kit.window.stage-2.3.12] startup
# [2.778s] [ext: omni.kit.property.layer-1.1.4] startup
# [2.780s] [ext: omni.kit.menu.edit-1.1.6] startup
# [2.781s] [ext: omni.kit.menu.file-1.1.4] startup
# [2.782s] [ext: omni.kit.menu.stage-1.2.1] startup
# [2.783s] [ext: omni.kit.property.audio-1.0.6] startup
# [2.784s] [ext: omni.kit.property.camera-1.0.3] startup
# [2.784s] [ext: omni.kit.property.geometry-1.2.2] startup
# [2.786s] [ext: omni.kit.property.light-1.0.6] startup
# [2.787s] [ext: omni.hydra.scene_api-0.1.1] startup
# [2.792s] [ext: omni.kit.property.material-1.8.19] startup
# [2.793s] [ext: omni.kit.property.render-1.1.0] startup
# [2.794s] [ext: omni.kit.property.skel-1.0.1] startup
# [2.795s] [ext: omni.kit.property.transform-1.3.5] startup
# [2.797s] [ext: omni.kit.manipulator.transform-104.6.12] startup
# [2.798s] [ext: omni.kit.widget.toolbar-1.4.0] startup
# [2.802s] [ext: omni.kit.profiler.window-2.0.5] startup
# [2.849s] [ext: omni.kit.property.bundle-1.2.6] startup
# [2.849s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [2.850s] [ext: omni.kit.manipulator.tool.snap-1.2.4] startup
# [2.854s] [ext: omni.kit.window.toolbar-1.4.0] startup
# [2.856s] [ext: omni.kit.property.isaac-0.2.0] startup
# [2.857s] [ext: omni.kit.stage_column.payload-1.0.8] startup
# [2.858s] [ext: omni.kit.manipulator.camera-104.0.23] startup
# [2.859s] [ext: omni.kit.manipulator.prim-104.10.7] startup
# [2.863s] [ext: omni.kit.manipulator.selection-104.0.6] startup
# [2.863s] [ext: omni.kit.viewport.menubar.display-104.1.11] startup
# [2.864s] [ext: omni.kit.viewport.menubar.camera-104.1.9] startup
# [2.867s] [ext: omni.rtx.window.settings-0.6.2] startup
# [2.870s] [ext: omni.kit.viewport.menubar.settings-104.3.5] startup
# [2.873s] [ext: omni.kit.viewport.menubar.render-104.0.20] startup
# [2.875s] [ext: omni.physx.commands-104.2.4-5.1] startup
# [2.878s] [ext: omni.kit.stage_column.variant-1.0.9] startup
# [2.879s] [ext: omni.hydra.pxr.settings-1.0.3] startup
# [2.880s] [ext: omni.kit.viewport.bundle-104.0.2] startup
# [2.880s] [ext: omni.physx.ui-104.2.4-5.1] startup
# [2.918s] [ext: omni.kit.viewport.menubar.lighting-104.0.9] startup
# [2.920s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [2.920s] [ext: omni.kit.viewport.ready-1.0.2] startup
# [2.921s] [ext: omni.physx.demos-104.2.4-5.1] startup
# [2.922s] [ext: omni.kit.property.physx-0.1.0] startup
# [2.954s] [ext: omni.isaac.urdf-0.5.9] startup
# [2.973s] [ext: omni.kit.widget.highlight_label-1.0.0] startup
# [2.974s] [ext: omni.physx.supportui-104.2.4-5.1] startup
# [3.061s] [ext: omni.physx.vehicle-104.2.4-5.1] startup
# [3.068s] [ext: omni.physx.cct-104.2.4-5.1] startup
# [3.073s] [ext: omni.physx.camera-104.2.4-5.1] startup
# [3.077s] [ext: omni.kit.actions.window-1.1.0] startup
# [3.080s] [ext: omni.kit.window.commands-0.2.4] startup
# [3.081s] [ext: omni.kit.window.console-0.2.3] startup
# [3.087s] [ext: omni.physx.bundle-104.2.4-5.1] startup
# [3.087s] [ext: omni.graph.bundle.action-1.3.0] startup
# [3.087s] [ext: omni.kit.window.script_editor-1.7.2] startup
# [3.089s] [ext: omni.kit.hotkeys.window-1.1.3] startup
# [3.092s] [ext: omni.kit.window.status_bar-0.1.5] startup
# [3.095s] [ext: omni.kit.window.title-1.1.2] startup
# [3.095s] [ext: omni.replicator.composer-1.2.10] startup
# [3.098s] [ext: omni.replicator.isaac-1.7.4] startup
# [3.108s] [ext: omni.resourcemonitor-1.0.0] startup
# [3.112s] [ext: omni.rtx.settings.core-0.5.8] startup
# [3.115s] [ext: omni.isaac.franka-0.4.0] startup
# [3.116s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [3.116s] [ext: semantics.schema.editor-0.3.3] startup
# [3.118s] [ext: omni.kit.widget.live-2.0.3] startup
# [3.119s] [ext: omni.isaac.utils-0.2.4] startup
# [3.122s] [ext: omni.isaac.kit-1.4.1] startup
# [3.122s] [ext: omni.isaac.cortex-0.3.2] startup
# [3.122s] [ext: omni.kit.window.stats-0.1.2] startup
# [3.123s] [ext: omni.isaac.sim.python-2022.2.1] startup
# [3.124s] Simulation App Starting
# Saving a temp livesync stage at  omniverse://localhost/Users/lm-2023/.local/share/ov/data/temp_jupyter_stage.usd  ...2023-06-21 19:25:22 [4,137ms] [Warning] [omni.usd] Default value for render setting "/rtx/shaderDb/cachePermutationIndex" not found
# 2023-06-21 19:25:22 [4,138ms] [Warning] [omni.usd] Default value for render setting "/rtx/pathtracing/nrc/canRun" not found
# 2023-06-21 19:25:22 [4,139ms] [Warning] [omni.usd] Default value for render setting "/rtx/multiThreading/enabled" not found
# 2023-06-21 19:25:22 [4,139ms] [Warning] [omni.usd] Default value for render setting "/rtx/hydra/mdlMaterialWarmup" not found
# Done.
# 2023-06-21 19:25:22 [4,149ms] [Error] [omni.usd] ERROR! Cannot save layer anon:0x1472b7c0:World0.usd to new path as new path omniverse://localhost/Users/lm-2023/.local/share/ov/data/temp_jupyter_stage.usd cannot be opened.
# 2023-06-21 19:25:22 [4,149ms] [Error] [omni.usd] Failed to save layer anon:0x1472b7c0:World0.usd to new path omniverse://localhost/Users/lm-2023/.local/share/ov/data/temp_jupyter_stage.usd
# Hi

# %% [markdown]
# # Iterative Development
#
# Once `simulation_app` is up and running in your notebook, the iterative development process begins. The iterative development process consists of creating a scene, or stage in usd lingo, and then viewing and interacting with it. There are two ways to view and interact with your stage; with `simulation_app` in this python notebook, or with an external Omniverse viewer, like vanilla Kit or IsaacSim. To use the external viewer, just open the `livesync_usd` file and make sure live update is on the root layer
#
# ## Create a simulation context and move camera
#
# Here we create a `SimulationContext` object which provides a high level interface to interact with the simulation

# %%
from omni.isaac.core import World
from omni.isaac.core.utils.prims import create_prim
from omni.isaac.core.utils.viewports import set_camera_view
from omni.isaac.core.utils.nucleus import get_assets_root_path
from omni.isaac.core.materials.omni_glass import OmniGlass
from omni.isaac.core.prims.xform_prim import XFormPrim
from omni.isaac.core.utils.extensions import get_extension_path_from_name
from omni.isaac.core.utils.semantics import add_update_semantics

import omni
import carb
import numpy as np

simulation_world = World(stage_units_in_meters=1.0)
set_camera_view(eye=np.array([-0.9025, 2.1035, 1.0222]), target=np.array([0.6039, 0.30, 0.0950]))

# Step our simulation to ensure everything initialized
simulation_world.step()

# %% [markdown]
# ## Creating the scene
#
# Re-run the cell below to randomize the scene from scratch. The goal here is to make iterating on scene setup easy and not require restarts of the omniverse application.

# %%
# Delete everything in the stage
simulation_world.clear()
# SCENE SETUP

# Add a distant light
create_prim("/DistantLight", "DistantLight", attributes={"intensity": 500})

# Add a ground collision plane
simulation_world.scene.add_ground_plane(size=1000, z_position=-0.5, color=np.array([1, 1, 1]))

# Load a URDF
status, import_config = omni.kit.commands.execute("URDFCreateImportConfig")
import_config.merge_fixed_joints = False
import_config.convex_decomp = False
import_config.import_inertia_tensor = True
import_config.fix_base = False
import_config.distance_scale = 1.0
import_config.create_physics_scene = False  # we already have a physics scene from simulation_world

# Get path to extension data:
extension_path = get_extension_path_from_name("omni.isaac.urdf")
# Import URDF, stage_path contains the path the path to the usd prim in the stage.
status, stage_path = omni.kit.commands.execute(
    "URDFParseAndImportFile",
    urdf_path=extension_path + "/data/urdf/robots/carter/urdf/carter.urdf",
    import_config=import_config,
)
stage = simulation_world.stage
add_update_semantics(stage.GetPrimAtPath(stage_path), "Robot")

# Load a mesh
assets_root_path = get_assets_root_path()
if assets_root_path is None:
    carb.log_error("Could not find Isaac Sim assets folder")
usd_path = assets_root_path + "/Isaac/Props/YCB/Axis_Aligned/006_mustard_bottle.usd"

prim = create_prim(prim_path="/Mesh", usd_path=usd_path, scale=np.array([10.0, 10.0, 10.0]), semantic_label="mustard")
xform_prim = XFormPrim(prim.GetPath())


# Apply a glass material to mesh
material = OmniGlass(
    "/Looks/GlassMaterial", name="glass_material", ior=1.25, depth=0.001, thin_walled=False, color=np.random.rand(3)
)
xform_prim.apply_visual_material(material)

# Set mesh transform
xform_prim.set_world_pose(position=np.array([1.00, 0, 0]))

# %% [markdown]
# ## Viewing the scene in the notebook
#
# This next example does not change the scene (but it could if you used commands like the ones above), but it does use the IsaacSim's `SyntheticDataHelper` to view the data. Specifically, it shows a color, depth, and segmentation view of the scene, and then displays them within the notebook.

# %%
import matplotlib.pyplot as plt
from omni.syntheticdata import visualize
from omni.kit.viewport.utility import get_active_viewport
import omni.replicator.core as rep

viewport_api = get_active_viewport()
active_cam = viewport_api.get_active_camera()
resolution = viewport_api.get_texture_resolution()
render_product = rep.create.render_product(active_cam, resolution)

rgb = rep.AnnotatorRegistry.get_annotator("rgb")
rgb.attach([render_product])
depth = rep.AnnotatorRegistry.get_annotator("distance_to_image_plane")
depth.attach([render_product])
semantic_segmentation = rep.AnnotatorRegistry.get_annotator("semantic_segmentation")
semantic_segmentation.attach([render_product])

# Run the application for multiple frames to ensure the synthetic data pipeline is initialized
timeline = omni.timeline.get_timeline_interface()
timeline.play()
for _ in range(10):
    simulation_app.update()
timeline.pause()

# Get groundtruth
rgb_data = rgb.get_data()
depth_data = depth.get_data()
semantic_segmentation_data = semantic_segmentation.get_data()

# GROUNDTRUTH VISUALIZATION
# Setup a figure
_, axes = plt.subplots(1, 3, figsize=(20, 7))
axes = axes.flat
for ax in axes:
    ax.axis("off")

# RGB
axes[0].set_title("RGB")
axes[0].imshow(rgb_data)

# DEPTH
axes[1].set_title("Depth")
depth_data_clipped = np.clip(depth_data, 0, 255)
axes[1].imshow(visualize.colorize_distance(depth_data.squeeze()))

# SEMANTIC SEGMENTATION
axes[2].set_title("Semantic Segmentation")
# Draw the segmentation mask on top of the color image with a transparency
axes[2].imshow(rgb_data)
semantic_segmentation_rgb = visualize.colorize_segmentation(semantic_segmentation_data["data"])
axes[2].imshow(semantic_segmentation_rgb, alpha=0.7)

# %%
# Cleanup application
simulation_app.close()
